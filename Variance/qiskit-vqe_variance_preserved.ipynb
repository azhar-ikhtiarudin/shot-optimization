# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit import Aer, execute
from qiskit.visualization import plot_histogram
from qiskit.tools.visualization import plot_histogram, plot_state_city
from qiskit.tools.monitor import job_monitor
# from azure.quantum.qiskit import AzureQuantumProvider
from qiskit_aer.noise import NoiseModel, depolarizing_error, pauli_error
from qiskit.utils import QuantumInstance

import numpy as np
import math
from scipy.linalg import block_diag
from scipy.optimize import minimize
from scipy.optimize import OptimizeResult, approx_fprime
import argparse


p_reset = 0.1
p_meas = 0.1
p_gate1 = 0.1
p_phase = 0.1

# QuantumError objects
error_reset = pauli_error([('X', p_reset), ('I', 1 - p_reset)])
error_meas = pauli_error([('X',p_meas), ('I', 1 - p_meas)])
error_gate1 = pauli_error([('X',p_gate1), ('I', 1 - p_gate1)])
error_gate2 = error_gate1.tensor(error_gate1)
error_phase = pauli_error([('Z',p_phase), ('I', 1 - p_phase)])

# Add errors to noise model
noise_model = NoiseModel()
noise_model.add_all_qubit_quantum_error(error_reset, "reset")
noise_model.add_all_qubit_quantum_error(error_meas, "measure")
noise_model.add_all_qubit_quantum_error(error_gate1.compose(error_phase), ["u1", "u2", "u3"])
noise_model.add_all_qubit_quantum_error(error_gate2.compose(error_phase.tensor(error_phase)), ["cx"])

# Here, we use parameters given for H2 at R=1.75A
g0 = -0.5597
g1 = +0.1615
g2 = -0.0166
g3 = +0.4148
g4 = +0.1226
g5 = +0.1226

nuclear_repulsion = 0.3023869942
Energy_FCI = -0.97516853

def func_and_gradient(x_opt, fun, eps):
    f = fun(x_opt)
    grad = np.zeros_like(x_opt)

    for i in range(x_opt.size):
        x_plus_h = x_opt.copy()
        x_plus_h[i] += eps
        f_plus_h = fun(x_plus_h)
        grad[i] = (f_plus_h - f) / eps

    return f, grad


def adam(fun, x0, iters=100, options=None, beta1=0.9, beta2=0.999, epsilon=1e-8, eps=0.02):
    # learning rate
    base_lr = 0.1

    # Initialize the ADAM variables
    t = 0
    m_t = 0
    v_t = 0

    # Initialize the optimization result
    nit = 0
    nfev = 0
    njev = 0
    success = False
    message = ''
    fun_val = np.inf
    x_opt = np.copy(x0)

    if options is None:
        options = {}
    maxiter = options.get('maxiter', iters)

    while nit < maxiter:
        print(nit)
        # Compute the function value and gradient
        fval, grad = func_and_gradient(x_opt, fun, eps)
        nfev += 2
        njev += 1

        fun_val = fval
        # Compute the ADAM update
        t += 1
        m_t = beta1 * m_t + (1 - beta1) * grad
        v_t = beta2 * v_t + (1 - beta2) * grad ** 2
        m_t_hat = m_t / (1 - beta1 ** t)
        v_t_hat = v_t / (1 - beta2 ** t)
        lr_current = 0.5 * base_lr * (math.cos(math.pi * nit / maxiter) + 1)
        lr = lr_current / (np.sqrt(v_t_hat) + epsilon)

        # Update the parameters
        x_opt = x_opt - lr * m_t_hat

        nit += 1

    result = OptimizeResult(fun=fun_val, x=x_opt, nit=nit, nfev=nfev, njev=njev, success=success, message=message)

    return result


def get_probability_distribution_2(counts, NUM_SHOTS):

    for k in {'00', '01', '10', '11'}:
        if k not in counts.keys():
            counts[k] = 0
    sorted_counts = sorted(counts.items())

    output_distr = [v[1] / NUM_SHOTS for v in sorted_counts]
    if len(output_distr) == 1:
        output_distr.append(1 - output_distr[0])
    return output_distr


class history:
    def __init__(self):
        self.thetas = []
        self.energies = []
        self.P1 = []
        self.P2 = []
        self.P3 = []
        self.shots = []


def simulator_std_estimation(theta, per_shots):
    # Get the expectation value of the first three terms <Z0>, <Z1>, <Z0Z1>
    circ = QuantumCircuit(2,2)
    circ.name = "H2 STO-3G g1-g3"
    circ.x(0)
    circ.ry(np.pi/2,1)
    circ.rx(3*np.pi/2,0)
    circ.cx(1,0)
    circ.rz(theta[0],0)
    circ.cx(1,0)
    circ.ry(3*np.pi/2,1)
    circ.rx(np.pi/2,0)
    circ.measure([0,1], [0,1])

    # Get the expectation value of <Y0Y1>
    circ_2 = QuantumCircuit(2,2)
    circ_2.name = "H2 STO-3G g4"
    circ_2.x(0)
    circ_2.ry(np.pi/2,1)
    circ_2.rx(3*np.pi/2,0)
    circ_2.cx(1,0)
    circ_2.rz(theta[0],0)
    circ_2.cx(1,0)
    circ_2.ry(3*np.pi/2,1)
    circ_2.rx(np.pi/2,0)
    circ_2.sdg(1)
    circ_2.h(1)
    circ_2.sdg(0)
    circ_2.h(0)
    circ_2.measure([0,1], [0,1])

    # Get the expectation value of <X0X1>
    circ_3 = QuantumCircuit(2,2)
    circ_3.name = "H2 STO-3G g5"
    circ_3.x(0)
    circ_3.ry(np.pi/2,1)
    circ_3.rx(3*np.pi/2,0)
    circ_3.cx(1,0)
    circ_3.rz(theta[0],0)
    circ_3.cx(1,0)
    circ_3.ry(3*np.pi/2,1)
    circ_3.rx(np.pi/2,0)
    circ_3.h(1)
    circ_3.h(0)
    circ_3.measure([0,1], [0,1])

    job = execute(circ, Aer.get_backend('qasm_simulator', noise_model=noise_model), shots=per_shots, memory=True)
    result = job.result()
    experiments = np.zeros((per_shots, 4))

    for idx, exp in enumerate(result.get_memory()):
        if exp == '00':
            experiments[idx, 0] = 1
        elif exp == '01':
            experiments[idx, 1] = 1
        elif exp == '10':
            experiments[idx, 2] = 1
        else:
            experiments[idx, 3] = 1

    E1_ = -g1 * (experiments[:,0] + experiments[:,1] - experiments[:,2] - experiments[:,3])
    E2_ = -g2 * (experiments[:,0] - experiments[:,1] + experiments[:,2] - experiments[:,3])
    E3_ = g3 * (experiments[:,0] - experiments[:,1] - experiments[:,2] + experiments[:,3])
    G13_ = E1_ + E2_ + E3_

    job = execute(circ_2, Aer.get_backend('qasm_simulator', noise_model=noise_model), shots=per_shots, memory=True)
    result = job.result()
    experiments = np.zeros((per_shots, 4))
    for idx, exp in enumerate(result.get_memory()):
        if exp == '00':
            experiments[idx, 0] = 1
        elif exp == '01':
            experiments[idx, 1] = 1
        elif exp == '10':
            experiments[idx, 2] = 1
        else:
            experiments[idx, 3] = 1
    E4_ = g4 * (experiments[:,0] - experiments[:,1] - experiments[:,2] + experiments[:,3])
    G4_ = E4_


    job = execute(circ_3, Aer.get_backend('qasm_simulator', noise_model=noise_model), shots=per_shots, memory=True)
    result = job.result()
    experiments = np.zeros((per_shots, 4))
    for idx, exp in enumerate(result.get_memory()):
        if exp == '00':
            experiments[idx, 0] = 1
        elif exp == '01':
            experiments[idx, 1] = 1
        elif exp == '10':
            experiments[idx, 2] = 1
        else:
            experiments[idx, 3] = 1
    # print(experiments)
    E5_ = g5 * (experiments[:,0] - experiments[:,1] - experiments[:,2] + experiments[:,3])
    G5_ = E5_
    return G13_, G4_, G5_


def simulator(theta, shots, std_shots, history):
    E = g0 + nuclear_repulsion

    # Get the expectation value of the first three terms <Z0>, <Z1>, <Z0Z1>
    circ = QuantumCircuit(2,2)
    circ.name = "H2 STO-3G g1-g3"
    circ.x(0)
    circ.ry(np.pi/2,1)
    circ.rx(3*np.pi/2,0)
    circ.cx(1,0)
    circ.rz(theta[0],0)
    circ.cx(1,0)
    circ.ry(3*np.pi/2,1)
    circ.rx(np.pi/2,0)
    circ.measure([0,1], [0,1])

    # Get the expectation value of <Y0Y1>
    circ_2 = QuantumCircuit(2,2)
    circ_2.name = "H2 STO-3G g4"
    circ_2.x(0)
    circ_2.ry(np.pi/2,1)
    circ_2.rx(3*np.pi/2,0)
    circ_2.cx(1,0)
    circ_2.rz(theta[0],0)
    circ_2.cx(1,0)
    circ_2.ry(3*np.pi/2,1)
    circ_2.rx(np.pi/2,0)
    circ_2.sdg(1)
    circ_2.h(1)
    circ_2.sdg(0)
    circ_2.h(0)
    circ_2.measure([0,1], [0,1])

    # Get the expectation value of <X0X1>
    circ_3 = QuantumCircuit(2,2)
    circ_3.name = "H2 STO-3G g5"
    circ_3.x(0)
    circ_3.ry(np.pi/2,1)
    circ_3.rx(3*np.pi/2,0)
    circ_3.cx(1,0)
    circ_3.rz(theta[0],0)
    circ_3.cx(1,0)
    circ_3.ry(3*np.pi/2,1)
    circ_3.rx(np.pi/2,0)
    circ_3.h(1)
    circ_3.h(0)
    circ_3.measure([0,1], [0,1])


    G13, G4, G5 = simulator_std_estimation(theta, std_shots)

    std = [np.std(G13), np.std(G4), np.std(G5)]
    # print(std)

    if sum(std)==0:
        ratio_for_theta = [1/3, 1/3, 1/3]
    else:
        ratio_for_theta = [v/sum(std) for v in std]

    std = [np.std(G13), np.std(G4), np.std(G5)]

    if sum(std)==0:
        ratio_for_theta = [1/3, 1/3, 1/3]
    else:
        ratio_for_theta = [v/sum(std) for v in std]
    
    # NEW SHOTS EQUATION
    newshots = (shots - std_shots*3)*sum(ratio_for_theta)**2/3/sum([v**2 for v in ratio_for_theta])
    print(shots, shots - std_shots*3, newshots)

    shots1 = round(newshots * ratio_for_theta[0])
    if shots1 < 1:
        shots1 = 1
   
    shots2 = round(newshots * ratio_for_theta[1])
    if shots2 < 1:
        shots2 = 1
   
    shots3 = round(newshots * ratio_for_theta[2])
    if shots3 < 1:
        shots3 = 1
    
    history.shots.append(shots1+shots2+shots3+std_shots*3)
    print('current assignment {} {} {} std shot assignment {}'.format(shots1, shots2, shots3, std_shots))


    job = execute(circ, Aer.get_backend('qasm_simulator', noise_model=noise_model), shots=shots1)
    result = job.result()

    counts = result.get_counts(circ)
    output_distr = get_probability_distribution_2(counts, shots1)
    history.P1.append(output_distr)

    E1 = -g1 * (output_distr[0] + output_distr[1] - output_distr[2] - output_distr[3])
    E2 = -g2 * (output_distr[0] - output_distr[1] + output_distr[2] - output_distr[3])
    E3 = g3 * (output_distr[0] - output_distr[1] - output_distr[2] + output_distr[3])
    E += (shots1*(E1 + E2 + E3) + np.sum(G13))/(shots1+std_shots)

    job = execute(circ_2, Aer.get_backend('qasm_simulator', noise_model=noise_model), shots=shots2)
    result = job.result()
    counts = result.get_counts(circ_2)
    output_distr = get_probability_distribution_2(counts, shots2)
    E4 = g4 * (output_distr[0] - output_distr[1] - output_distr[2] + output_distr[3])
    E += (shots2*E4 + np.sum(G4))/(shots2+std_shots)
    history.P2.append(output_distr)


    job = execute(circ_3, Aer.get_backend('qasm_simulator', noise_model=noise_model), shots=shots3)
    result = job.result()
    counts = result.get_counts(circ_3)
    output_distr = get_probability_distribution_2(counts, shots3)
    E5 = g5 * (output_distr[0] - output_distr[1] - output_distr[2] + output_distr[3])
    E += (shots3*E5 + np.sum(G5))/(shots3+std_shots)
    history.P3.append(output_distr)

    history.thetas.append(theta[0])
    history.energies.append(E)

    print('energy track: ', history.energies[-1])

    return E

# %%
theta_test = [-2]

record_history = history()
shots = 600
std_shots = 5

# ADAM optimizer
result = adam(lambda x: simulator(x, shots=shots, std_shots=std_shots, history=record_history), theta_test, iters=500, eps=0.02)
# Out:
# 0
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.3538920058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5248680057999999
# 1
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.3788260058
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.37359900579999983
# 2
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.37526400579999997
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.38238800580000004
# 3
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4339406724666667
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.3912930058
# 4
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.3984170057999999
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.3930740058
# 5
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.39251900580000004
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4001980057999999
# 6
# 600 585 361.5787920748629
# current assignment 231 130 1 std shot assignment 5
# energy track:  -0.40519409807871937
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.3877310057999999
# 7
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4037600058
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.4151170058
# 8
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.3859500058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.3930740058
# 9
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.41266500579999993
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4233510057999999
# 10
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.40910300579999986
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.42513200579999993
# 11
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4304750057999999
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4162270058
# 12
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4411610058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.43225600579999995
# 13
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.41444600579999996
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.43225600579999995
# 14
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4393800058
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.4233510058
# 15
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4180080058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.40910300579999986
# 16
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4358180057999999
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.43759900579999994
# 17
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.42157000579999987
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.41444600579999996
# 18
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.42513200579999993
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4286940058
# 19
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4108840058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4055410057999999
# 20
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.42513200579999993
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4162270058
# 21
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4180080058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4233510058
# 22
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4482850057999999
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.40910300579999986
# 23
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.48034300579999994
# 600 585 361.5787920748629
# current assignment 231 1 130 std shot assignment 5
# energy track:  -0.47372753812893903
# 141
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.48346600580000004
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4518470058
# 142
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4518470058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4714380057999999
# 143
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.47500000579999996
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.46965700579999986
# 144
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.46787600579999994
# 600 585 377.1520000804272
# current assignment 223 1 154 std shot assignment 5
# energy track:  -0.4940105066275405
# 145
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.46965700579999986
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.4823560058
# 146
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4518470058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.46787600579999994
# 147
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.48034300579999994
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.49181600579999996
# 148
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5017150058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.49815300579999994
# 149
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4660950058
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.49815300579999994
# 150
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4963720057999999
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5140856724666666
# 151
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.49993400579999997
# 600 585 361.5787920748629
# current assignment 231 1 130 std shot assignment 5
# energy track:  -0.5111791639920904
# 152
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -0.6099170058000001
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5195250057999998
# 153
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4963720057999999
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5798863391333333
# 154
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.4821240058
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.6258550058000001
# 155
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.5232280058000001
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5088390057999999
# 156
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.6405670058000001
# 600 585 377.1520000804272
# current assignment 223 154 1 std shot assignment 5
# energy track:  -0.5297616817351208
# 157
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5266490058
# 600 585 539.1618914840676
# current assignment 254 143 143 std shot assignment 5
# energy track:  -0.5763242027111969
# 158
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5603916724666665
# 600 585 377.1520000804272
# current assignment 223 154 1 std shot assignment 5
# energy track:  -0.5359302351942403
# 159
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -0.6258550058000001
# 600 585 377.1520000804272
# current assignment 223 1 154 std shot assignment 5
# energy track:  -0.5940222742541542
# 160
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5230870057999999
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.5811480058
# 161
# 600 585 377.1520000804272
# current assignment 223 1 154 std shot assignment 5
# energy track:  -0.5407983583322741
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5302110058
# 162
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5159630058
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -0.6246290058000001
# 163
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.6020810057999998
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5462400058000001
# 164
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5533640057999998
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.6368890058000001
# 165
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5498020057999999
# 600 585 377.1520000804272
# current assignment 223 154 1 std shot assignment 5
# energy track:  -0.6267495996430983
# 166
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.5622690057999999
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.6405010057999999
# 167
# 600 585 377.1520000804272
# current assignment 223 1 154 std shot assignment 5
# energy track:  -0.6484402484348891
# 600 585 565.5555919744426
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.6481657318330678
# 168
# 600 585 565.5555919744426
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.6481507757856333
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.6442450058000001
# 169
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -0.6191646724666667
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.7153530058
# 170
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.7022756724666668
# 600 585 377.1520000804272
# current assignment 223 1 154 std shot assignment 5
# energy track:  -0.6464291759423371
# 171
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.7492538443013583
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.7481290736591565
# 172
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.7302772669859978
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.7491093206992878
# 173
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.6625250058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.7668450058
# 174
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.6883810058000001
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.7182136724666668
# 175
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.7648561096901134
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.7872635516459332
# 176
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.7876870058000002
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.7878981987680694
# 177
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.7628653130454855
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.823168241308175
# 178
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.8124546438503307
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8244670058000002
# 179
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.8436591746278408
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.8450290070300754
# 180
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8379530058000002
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.7312910058000001
# 181
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8134330058000001
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.8494275514409207
# 182
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8502130058000001
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.861900566663103
# 183
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8661510058
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.8643360004524063
# 184
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.874518105487356
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.8649858313855673
# 185
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.8555415281719954
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8404050058000001
# 186
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.884597055823064
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8943490058000001
# 187
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.9875250058000001
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.8918358031963407
# 188
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.8996652122476451
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8894450058000002
# 189
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8845410058000002
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.876968723087684
# 190
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8906710058000001
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.9912030058000002
# 191
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.8517776308832865
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8845410058000002
# 192
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8796370058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9029310058000002
# 193
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.8833277615787916
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.8994201504876123
# 194
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -0.9899770058000001
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.8985844270495518
# 195
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9111579804296963
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8833150058000001
# 196
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8894450058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.8051593437632004
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -0.9466583391333334
# 234
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8207890058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8538910058000001
# 235
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8391790058000002
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8220150058000001
# 236
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.8199824384277486
# ...
# energy track:  -0.9530166388873937
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0365650058000002
# 426
# 600 585 565.5555919744427
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.9414544064379817
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9666830058000002
# 427
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9641792914849983
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9470670058000001
# 428
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9728130058000002
# 600 585 571.9980732090509
# current assignment 226 191 156 std shot assignment 5
# energy track:  -0.9497702723429807
# 429
# 600 585 377.1520000804272
# current assignment 223 154 1 std shot assignment 5
# energy track:  -0.981824127944985
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9651595385251296
# 430
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0267570058000002
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9707833917361387
# 431
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9642310058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9666830058000002
# 432
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9740390058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9777170058000001
# 433
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -1.0669170058000002
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.9797603391333335
# 434
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.9451670164951873
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9585554382739891
# 435
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0353390058000003
# 600 585 571.9980732090509
# current assignment 226 191 156 std shot assignment 5
# energy track:  -0.9583858863356134
# 436
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9875250058000002
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9665293709273642
# 437
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0169490058000001
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.95937236408877
# 438
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.9466696902919787
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9777170058000002
# 439
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0304350058
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9318363391333334
# 440
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0243050058000003
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9826210058000001
# 441
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9581010058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9605530058000001
# 442
# 600 585 565.5555919744427
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.958805233135817
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0414690058000002
# 443
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0304350058000002
# 600 585 377.1520000804272
# current assignment 223 154 1 std shot assignment 5
# energy track:  -0.9663624596232371
# 444
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0316610058000002
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9609495031604635
# 445
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9655491238872329
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0463730058
# 446
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0006023391333334
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.955329583340107
# 447
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9505815056206142
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9531970058000002
# 448
# 600 585 565.5555919744426
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.9558735458930188
# 600 585 565.5555919744426
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.935546163810081
# 449
# 600 585 387.1935534493815
# current assignment 210 1 177 std shot assignment 5
# energy track:  -1.0189474601828263
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.9367290058
# 450
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9642310058000002
# 600 585 565.5555919744426
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.9413646701533738
# 451
# 600 585 387.1935534493815
# current assignment 210 177 1 std shot assignment 5
# energy track:  -1.01729071599678
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9537107557871869
# 452
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0292090058000003
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0267570058000002
# 453
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.959680208916191
# 600 585 571.998073209051
# current assignment 226 156 191 std shot assignment 5
# energy track:  -0.9447117985186684
# 454
# 600 585 571.9980732090509
# current assignment 226 191 156 std shot assignment 5
# energy track:  -0.9297919657634318
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -1.0722600058
# 455
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9605530058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9011863391333332
# 456
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.9324960057999999
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.9343766421636364
# 457
# 600 585 387.1935534493815
# current assignment 210 1 177 std shot assignment 5
# energy track:  -1.021641965677332
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0426950058000002
# 458
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -1.0811650058000002
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.9400044496502674
# 459
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.9822123391333335
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9771424302272462
# 460
# 600 585 571.9980732090509
# current assignment 226 191 156 std shot assignment 5
# energy track:  -0.9466398106721466
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0218530058000002
# 461
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9642310058000002
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9743022272648149
# 462
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.8999603391333334
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9801690058000001
# 463
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9691350058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9581010058000001
# 464
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9715870058000002
# 600 585 571.998073209051
# current assignment 226 156 191 std shot assignment 5
# energy track:  -0.9605995939530478
# 465
# 600 585 565.5555919744426
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.9632476321423185
# 600 585 195.0
# current assignment 195 1 1 std shot assignment 5
# energy track:  -1.0224883391333333
# 466
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0181750058
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.9858903391333335
# 467
# 600 585 571.9980732090509
# current assignment 226 191 156 std shot assignment 5
# energy track:  -0.9420328466217042
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9657941856472658
# 468
# 600 585 571.9980732090509
# current assignment 226 191 156 std shot assignment 5
# energy track:  -0.9441567798313516
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -0.9871163391333335
# 469
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0316610058000002
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0230790058
# 470
# 600 585 565.5555919744426
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.9341850125207248
# 600 585 377.1520000804272
# current assignment 223 154 1 std shot assignment 5
# energy track:  -0.993269311658987
# 471
# 600 585 387.1935534493815
# current assignment 210 177 1 std shot assignment 5
# energy track:  -1.0126299748774343
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9666830058000001
# 472
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9669189562894676
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9605530058000001
# 473
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9727878712605096
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9593270058000002
# 474
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0316610058000002
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0304350058000002
# 475
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9771424302272462
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9568750058000002
# 476
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9617790058000001
# 600 585 585.0
# current assignment 195 195 195 std shot assignment 5
# energy track:  -0.9389490058000001
# 477
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.950480967462652
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.9254985672973263
# 478
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9676981270136745
# 600 585 565.5555919744427
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.9399137825794093
# 479
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9514612145027832
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9728130058000002
# 480
# 600 585 571.9980732090509
# current assignment 226 191 156 std shot assignment 5
# energy track:  -0.9548556693476326
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9789430058000003
# 481
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0365650058000002
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0353390058000003
# 482
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9531970058000001
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9608049795583928
# 483
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9568750058000001
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.95581577346952
# 484
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0292090058
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9614396266805292
# 485
# 600 585 387.1935534493815
# current assignment 210 1 177 std shot assignment 5
# energy track:  -0.9622232519879206
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0055063391333336
# 486
# 600 585 565.5555919744426
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.950055039549726
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0267570058000002
# 487
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9581010058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9642310058000002
# 488
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9728130058000001
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9617790058000001
# 489
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0279830058000001
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0377910058000002
# 490
# 600 585 565.5555919744427
# current assignment 238 164 164 std shot assignment 5
# energy track:  -0.9282618138453894
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9793919715116499
# 491
# 600 585 387.1935534493815
# current assignment 210 177 1 std shot assignment 5
# energy track:  -1.0115922135689752
# 600 585 571.998073209051
# current assignment 226 156 191 std shot assignment 5
# energy track:  -0.9601290742036461
# 492
# 600 585 387.1935534493815
# current assignment 210 177 1 std shot assignment 5
# energy track:  -0.9807752990106652
# 600 585 377.1520000804272
# current assignment 223 154 1 std shot assignment 5
# energy track:  -1.0195662332081428
# 493
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9472071936940086
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9566514969075806
# 494
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -0.9858903391333335
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0218530058000002
# 495
# 600 585 195.0
# current assignment 1 1 195 std shot assignment 5
# energy track:  -1.0267570058000002
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -0.9314276724666667
# 496
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9629539826848343
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9651155530810211
# 497
# 600 585 386.0601999370879
# current assignment 1 213 174 std shot assignment 5
# energy track:  -0.9686783740538056
# 600 585 195.0
# current assignment 1 195 1 std shot assignment 5
# energy track:  -1.0426950058000002
# 498
# 600 585 581.0346262302821
# current assignment 216 182 182 std shot assignment 5
# energy track:  -0.9436376047304813
# 600 585 386.0601999370879
# current assignment 1 174 213 std shot assignment 5
# energy track:  -0.9746478271828097
# 499
# 600 585 390.0
# current assignment 1 195 195 std shot assignment 5
# energy track:  -0.9556490058000001
# 600 585 571.998073209051
# current assignment 226 156 191 std shot assignment 5
# energy track:  -0.9450296926328358

# %%
import matplotlib.pyplot as plt 
plt.plot(record_history.energies)

# %%
print(record_history.shots)
# Out:
# [212, 212, 212, 600, 212, 212, 212, 212, 212, 212, 600, 212, 377, 212, 212, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 212, 212, 212, 212, 212, 212, 212, 600, 212, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 393, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 212, 212, 212, 212, 393, 212, 212, 212, 212, 212, 212, 393, 212, 212, 212, 212, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 212, 212, 212, 212, 212, 212, 600, 212, 600, 212, 212, 212, 377, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 600, 212, 600, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212, 212,